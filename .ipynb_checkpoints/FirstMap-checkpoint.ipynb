# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy

import numpy as np
from sklearn import preprocessing

# %%
central_lon, central_lat = -5, 55
extent = [-20, 30, 30, 60]

plt.figure()
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat))
ax.set_extent(extent)
ax.coastlines(resolution='50m')
ax.add_feature(cartopy.feature.BORDERS)
# Out:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:

# %%
df_gdp = pd.read_csv('gdp_2016.csv', delimiter=';')
df_gdp = df_gdp.rename(columns={'Country': 'CountryName'})
df_gdp = df_gdp.drop(['Abbreviation', 'Year'], axis=1)
# GDP read as object
df_gdp['GDP'] = df_gdp['GDP'].astype(str).astype(float)
df_gdp.head()
# list(df_gdp.columns)
# Out:
#    CountryName           GDP
# 0  Afghanistan  6.429743e+10
# 1      Albania  3.148182e+10
# 2      Algeria  5.746961e+11
# 3       Angola  1.783339e+11
# 4    Argentina  8.283729e+11

# %%
df_farms = pd.read_csv('EuropeanAgriculture_FarmStructureIndicators_Eurostat2016.csv')
df_farms.head()
# Out:
#     Country  farms_number  used_agricultural_area_ha  standard_output_EUR  \
# 0   Belgium         36890                    1354250         8.037986e+09
# 1  Bulgaria        202720                    4468500         3.842891e+09
# 2   Czechia         26530                    3455410                  NaN
# 3   Denmark         35050                    2614600         1.006244e+10
# 4   Germany        276120                   16715320         4.924902e+10
#
#    subsistence_semisubsistence_farms  total_labour_persons  total_labour_AWU  \
# 0                                NaN                 70910             55350
# 1                                0.0                439740            255520
# 2                             4120.0                130290            103270
# 3                                0.0                 73320             49480
# 4                                0.0                653760            502610
#
#    nonfamily_labour_persons  nonfamily_labour_AWU  managers_basic_training  \
# 0                   19800.0               14810.0                     9940
# 1                   64490.0               59100.0                     5360
# 2                   81840.0               71440.0                     4910
# 3                   25780.0               22840.0                    16340
# 4                  178640.0              148330.0                   133520
#
#    ...  farms_SO_less2000  farms_SO_2000-3999  farms_SO_4000-7999  \
# 0  ...                310                 580                1380
# 1  ...             105730               35210               22440
# 2  ...               1150                2840                4350
# 3  ...                600                 790                2480
# 4  ...                460                6790               21510
#
#    farms_SO_8000-14999  farms_SO_15000-24999  farms_SO_25000-49999  \
# 0                 2410                  2670                  4310
# 1                13590                  8450                  6780
# 2                 4320                  3050                  3200
# 3                 4920                  4740                  5510
# 4                33650                 29560                 37200
#
#    farms_SO_50000-99999  farms_SO_100000-249999  farms_SO_250000-499999  \
# 0                  5130                    9010                    7170
# 1                  4040                    2740                    1480
# 2                  2400                    2230                     980
# 3                  4260                    3910                    2170
# 4                 40100                   53820                   32350
#
#    farms_SO_500000_orover
# 0                    3880
# 1                    1510
# 2                    1930
# 3                    5510
# 4                   20430
#
# [5 rows x 24 columns]

# %%
df_coords = pd.read_csv('country-capitals.csv',on_bad_lines='skip')
df_coords.head()
# Out:
#                                 CountryName        CapitalName  \
# 0                                Somaliland           Hargeisa
# 1  South Georgia and South Sandwich Islands  King Edward Point
# 2       French Southern and Antarctic Lands  Port-aux-Français
# 3                                 Palestine          Jerusalem
# 4                             Aland Islands          Mariehamn
#
#    CapitalLatitude  CapitalLongitude CountryCode ContinentName
# 0         9.550000         44.050000         NaN        Africa
# 1       -54.283333        -36.500000          GS    Antarctica
# 2       -49.350000         70.216667          TF    Antarctica
# 3        31.766667         35.233333          PS          Asia
# 4        60.116667         19.900000          AX        Europe

# %%
df = pd.merge(
    df_farms, 
    df_coords, 
    how="left", 
    left_on="Country", 
    right_on="CountryName"
)
df = df.drop(['CountryName','ContinentName'], axis=1)
df.head(10)
# Out:
#     Country  farms_number  used_agricultural_area_ha  standard_output_EUR  \
# 0   Belgium         36890                    1354250         8.037986e+09
# 1  Bulgaria        202720                    4468500         3.842891e+09
# 2   Czechia         26530                    3455410                  NaN
# 3   Denmark         35050                    2614600         1.006244e+10
# 4   Germany        276120                   16715320         4.924902e+10
# 5   Estonia         16700                     995100         8.015471e+08
# 6   Ireland        137560                    4883650         6.324901e+09
# 7    Greece        684950                    4553830         7.574804e+09
# 8     Spain        945020                   23229750         3.836561e+10
# 9    France        456520                   27814160         6.134314e+10
#
#    subsistence_semisubsistence_farms  total_labour_persons  total_labour_AWU  \
# 0                                NaN                 70910             55350
# 1                                0.0                439740            255520
# 2                             4120.0                130290            103270
# 3                                0.0                 73320             49480
# 4                                0.0                653760            502610
# 5                             4900.0                 38380             19880
# 6                                NaN                265180            160740
# 7                           109600.0               1198390            457150
# 8                            33400.0               1866210            822370
# 9                             7040.0                859750            708170
#
#    nonfamily_labour_persons  nonfamily_labour_AWU  managers_basic_training  \
# 0                   19800.0               14810.0                     9940
# 1                   64490.0               59100.0                     5360
# 2                   81840.0               71440.0                     4910
# 3                   25780.0               22840.0                    16340
# 4                  178640.0              148330.0                   133520
# 5                   13450.0               11150.0                     1870
# 6                   18530.0               10000.0                    33790
# 7                   33830.0               24390.0                    42490
# 8                  351200.0              188590.0                   186720
# 9                  403750.0              334590.0                   129340
#
#    ...  farms_SO_15000-24999  farms_SO_25000-49999  farms_SO_50000-99999  \
# 0  ...                  2670                  4310                  5130
# 1  ...                  8450                  6780                  4040
# 2  ...                  3050                  3200                  2400
# 3  ...                  4740                  5510                  4260
# 4  ...                 29560                 37200                 40100
# 5  ...                  1030                  1000                   800
# 6  ...                 20760                 20390                 11710
# 7  ...                 58280                 47570                 15900
# 8  ...                 84760                 85680                 67220
# 9  ...                 31170                 51600                 68000
#
#    farms_SO_100000-249999  farms_SO_250000-499999  farms_SO_500000_orover  \
# 0                    9010                    7170                    3880
# 1                    2740                    1480                    1510
# 2                    2230                     980                    1930
# 3                    3910                    2170                    5510
# 4                   53820                   32350                   20430
# 5                     740                     300                     280
# 6                   12320                    3340                     870
# 7                    4450                     710                     330
# 8                   51150                   15980                   11080
# 9                  112690                   54410                   19470
#
#    CapitalName  CapitalLatitude  CapitalLongitude  CountryCode
# 0     Brussels        50.833333          4.333333           BE
# 1        Sofia        42.683333         23.316667           BG
# 2          NaN              NaN               NaN          NaN
# 3   Copenhagen        55.666667         12.583333           DK
# 4       Berlin        52.516667         13.400000           DE
# 5      Tallinn        59.433333         24.716667           EE
# 6       Dublin        53.316667         -6.233333           IE
# 7       Athens        37.983333         23.733333           GR
# 8       Madrid        40.400000         -3.683333           ES
# 9        Paris        48.866667          2.333333           FR
#
# [10 rows x 28 columns]

# %%
df = pd.merge(
    df, 
    df_gdp, 
    how="left", 
    left_on="Country", 
    right_on="CountryName"
)
df = df.drop(['CountryName'], axis=1)
df.head(10)
# Out:
#     Country  farms_number  used_agricultural_area_ha  standard_output_EUR  \
# 0   Belgium         36890                    1354250         8.037986e+09
# 1  Bulgaria        202720                    4468500         3.842891e+09
# 2   Czechia         26530                    3455410                  NaN
# 3   Denmark         35050                    2614600         1.006244e+10
# 4   Germany        276120                   16715320         4.924902e+10
# 5   Estonia         16700                     995100         8.015471e+08
# 6   Ireland        137560                    4883650         6.324901e+09
# 7    Greece        684950                    4553830         7.574804e+09
# 8     Spain        945020                   23229750         3.836561e+10
# 9    France        456520                   27814160         6.134314e+10
#
#    subsistence_semisubsistence_farms  total_labour_persons  total_labour_AWU  \
# 0                                NaN                 70910             55350
# 1                                0.0                439740            255520
# 2                             4120.0                130290            103270
# 3                                0.0                 73320             49480
# 4                                0.0                653760            502610
# 5                             4900.0                 38380             19880
# 6                                NaN                265180            160740
# 7                           109600.0               1198390            457150
# 8                            33400.0               1866210            822370
# 9                             7040.0                859750            708170
#
#    nonfamily_labour_persons  nonfamily_labour_AWU  managers_basic_training  \
# 0                   19800.0               14810.0                     9940
# 1                   64490.0               59100.0                     5360
# 2                   81840.0               71440.0                     4910
# 3                   25780.0               22840.0                    16340
# 4                  178640.0              148330.0                   133520
# 5                   13450.0               11150.0                     1870
# 6                   18530.0               10000.0                    33790
# 7                   33830.0               24390.0                    42490
# 8                  351200.0              188590.0                   186720
# 9                  403750.0              334590.0                   129340
#
#    ...  farms_SO_25000-49999  farms_SO_50000-99999  farms_SO_100000-249999  \
# 0  ...                  4310                  5130                    9010
# 1  ...                  6780                  4040                    2740
# 2  ...                  3200                  2400                    2230
# 3  ...                  5510                  4260                    3910
# 4  ...                 37200                 40100                   53820
# 5  ...                  1000                   800                     740
# 6  ...                 20390                 11710                   12320
# 7  ...                 47570                 15900                    4450
# 8  ...                 85680                 67220                   51150
# 9  ...                 51600                 68000                  112690
#
#    farms_SO_250000-499999  farms_SO_500000_orover  CapitalName  \
# 0                    7170                    3880     Brussels
# 1                    1480                    1510        Sofia
# 2                     980                    1930          NaN
# 3                    2170                    5510   Copenhagen
# 4                   32350                   20430       Berlin
# 5                     300                     280      Tallinn
# 6                    3340                     870       Dublin
# 7                     710                     330       Athens
# 8                   15980                   11080       Madrid
# 9                   54410                   19470        Paris
#
#    CapitalLatitude  CapitalLongitude  CountryCode           GDP
# 0        50.833333          4.333333           BE  4.393590e+11
# 1        42.683333         23.316667           BG  1.238846e+11
# 2              NaN               NaN          NaN  3.038507e+11
# 3        55.666667         12.583333           DK  2.568218e+11
# 4        52.516667         13.400000           DE  3.735419e+12
# 5        59.433333         24.716667           EE  3.196262e+10
# 6        53.316667         -6.233333           IE  2.686955e+11
# 7        37.983333         23.733333           GR  2.416539e+11
# 8        40.400000         -3.683333           ES  1.417044e+12
# 9        48.866667          2.333333           FR  2.479390e+12
#
# [10 rows x 29 columns]

# %% [markdown]
# ## Looking at data (above)
# - Could be interesting to see how the distribution of farms changes using the farm_SO_(value) columns
#     - A stacked bar graph could give. a quick check of what is actually happening in each nation as far as income distribution goes
#     - Done
# - Take a closer look at subsistence farms
#     - How do these correlate with
# - How do all of these metrics correlate with agricultural output?
#     - More subsistence farms higher or lower output => what nuance is this missing?
# - How does manager training impact output at a country level?
#     - Need more context as to what the training actually means?
# - Plot laborers per farm and per ha on a map
#     - What countries are using their resources most effectively
#
# ## Scale Columns
# - Normalizes the data so it's easier for me to scale variables
# - Makes it easier to compare similar data points for the chart

# %%
df["labor_per_ha"] = df["total_labour_persons"]/df["used_agricultural_area_ha"]

# %%
def scaleColumns(df, cols_to_scale):
    for col in cols_to_scale:
        new_col_name = col+'_normalized'
        df[new_col_name] = pd.DataFrame(min_max_scaler.fit_transform(pd.DataFrame(df[col])),columns=[col]) * 1000
    return df

# %%
min_max_scaler = preprocessing.MinMaxScaler()

df = scaleColumns(df, ['farms_number','used_agricultural_area_ha','standard_output_EUR'])

# %%
print(df.dtypes)
# Out:
# Country                                  object
# farms_number                              int64
# used_agricultural_area_ha                 int64
# standard_output_EUR                     float64
# subsistence_semisubsistence_farms       float64
# total_labour_persons                      int64
# total_labour_AWU                          int64
# nonfamily_labour_persons                float64
# nonfamily_labour_AWU                    float64
# managers_basic_training                   int64
# managers_only_practical                   int64
# managers_full_training                    int64
# managers_training_NA                    float64
# farms_SO_zero                           float64
# farms_SO_less2000                         int64
# farms_SO_2000-3999                        int64
# farms_SO_4000-7999                        int64
# farms_SO_8000-14999                       int64
# farms_SO_15000-24999                      int64
# farms_SO_25000-49999                      int64
# farms_SO_50000-99999                      int64
# farms_SO_100000-249999                    int64
# farms_SO_250000-499999                    int64
# farms_SO_500000_orover                    int64
# CapitalName                              object
# CapitalLatitude                         float64
# CapitalLongitude                        float64
# CountryCode                              object
# GDP                                     float64
# labor_per_ha                            float64
# farms_number_normalized                 float64
# used_agricultural_area_ha_normalized    float64
# standard_output_EUR_normalized          float64
# dtype: object

# %%
central_lon, central_lat = -5, 55
extent = [-20, 30, 30, 60]

plt.figure()
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat))

# print(df['CapitalLongitude'], df['CapitalLatitude'])
cmap = plt.cm.rainbow

for i in df.itertuples():
    plt.text(i.CapitalLongitude, i.CapitalLatitude, i.CountryCode)
    ax.scatter(
        i.CapitalLongitude, 
        i.CapitalLatitude, 
        s=i.used_agricultural_area_ha_normalized,
        # s=i.farms_number_normalized,
        # color='blue', 
        # color = cmap(i.used_agricultural_area_ha_normalized),
        # color = cmap(i.farms_number_normalized),
        transform=ccrs.PlateCarree()
    )

ax.set_extent(extent)
ax.coastlines(resolution='50m')
ax.add_feature(cartopy.feature.BORDERS)

plt.show()
# plt.savefig('used_agricultural_area_ha_normalized')
# Out:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
df_stacked = df[[
    'CountryCode',
    'farms_SO_zero',
    'farms_SO_less2000',
    'farms_SO_2000-3999',
    'farms_SO_4000-7999',
    'farms_SO_8000-14999',
    'farms_SO_15000-24999',
    'farms_SO_25000-49999',
    'farms_SO_50000-99999',
    'farms_SO_100000-249999',
    'farms_SO_250000-499999',
    'farms_SO_500000_orover'
    ]].copy()
df_stacked = df_stacked.set_index('CountryCode')
df_stacked.plot(kind='bar', stacked=True, legend=False)
# Out:
# <AxesSubplot:xlabel='CountryCode'>

# %% [markdown]
# ## What does this show us?
# - The vast majority of european farmers are Romanians that have an output of less than 2.000 euros
# - Not exactly sure what the output metric means
#     - data describes it as: *Number of farms with a Standard Output between 2.000-3.999 euros*
#     - average monetary value of the agricultural output at farm-gate price, in euro per hectare or per head of livestock.
# - What is the output / acre on these smaller farms?
# - Why do so many of them exist in Romania?

# %% [raw]
# # Correlation matrix
# df_corrs = df.corr()
# df_corrs.style.background_gradient()# cmap ='plasma')

# %% [markdown]
# ## Observations
# - GDP
#     - Initially I didn't include GDP in the analysis. It seemed like it would make a pretty big impact, but when you actually look at the numbers it's a leading indicator
#     - correlates well with used agricultural land, and standard output
#         - the higher your gdp the more land you might have and the higher your standard output would be
#         - I wonder if this changes if you calculate yield (output / landmass)
#     - I did expect GDP to be more tightly correlated with management. Pretty much random with a correlation coefficient of

# %%
df_corrs_standard_output = df_corrs[['farms_SO_zero',
    'farms_SO_less2000',
    'farms_SO_2000-3999',
    'farms_SO_4000-7999',
    'farms_SO_8000-14999',
    'farms_SO_15000-24999',
    'farms_SO_25000-49999',
    'farms_SO_50000-99999',
    'farms_SO_100000-249999',
    'farms_SO_250000-499999',
    'farms_SO_500000_orover'
]]

# %%
df_corrs_standard_output = df_corrs_standard_output.rename(columns={
    'farms_SO_zero':'0',
    'farms_SO_less2000': '<2k',
    'farms_SO_2000-3999': '2=>4',
    'farms_SO_4000-7999': '4=>8',
    'farms_SO_8000-14999': '8=>15',
    'farms_SO_15000-24999': '15=>25',
    'farms_SO_25000-49999': '25=>50',
    'farms_SO_50000-99999': '50=>100',
    'farms_SO_100000-249999': '100=>250',
    'farms_SO_250000-499999': '250=>500',
    'farms_SO_500000_orover': '500+'
})
df_corrs_standard_output=df_corrs_standard_output.transpose()

# %%
def drop_cols_for_corrs(df):
    return df.drop(columns = [
        'farms_SO_zero',
        'farms_SO_less2000',
        'farms_SO_2000-3999',
        'farms_SO_4000-7999',
        'farms_SO_8000-14999',
        'farms_SO_15000-24999',
        'farms_SO_25000-49999',
        'farms_SO_50000-99999',
        'farms_SO_100000-249999',
        'farms_SO_250000-499999',
        'farms_SO_500000_orover',
        'CapitalLatitude',
        'CapitalLongitude',
        'farms_number_normalized',
        'used_agricultural_area_ha_normalized',
        'standard_output_EUR_normalized'
    ])

# %%
df_corrs_standard_output = drop_cols_for_corrs(df_corrs_standard_output)
# df_corrs_standard_output = df_corrs_standard_output.transpose()

df_corrs_standard_output.head()
# Out:
#        farms_number  used_agricultural_area_ha  standard_output_EUR  \
# 0          0.962286                   0.366382             0.155028
# <2k        0.933195                   0.239697             0.038801
# 2=>4       0.990274                   0.385818             0.226586
# 4=>8       0.951567                   0.478039             0.333809
# 8=>15      0.748964                   0.587071             0.514233
#
#        subsistence_semisubsistence_farms  total_labour_persons  \
# 0                               0.888534              0.963035
# <2k                             0.992154              0.911749
# 2=>4                            0.885381              0.989347
# 4=>8                            0.748283              0.964898
# 8=>15                           0.397000              0.781925
#
#        total_labour_AWU  nonfamily_labour_persons  nonfamily_labour_AWU  \
# 0              0.866147                  0.191449              0.166251
# <2k            0.708428                  0.072857              0.067063
# 2=>4           0.890800                  0.241020              0.187890
# 4=>8           0.941288                  0.346565              0.272503
# 8=>15          0.893242                  0.508870              0.403339
#
#        managers_basic_training  managers_only_practical  \
# 0                     0.268069                 0.924405
# <2k                   0.102444                 0.981491
# 2=>4                  0.399848                 0.920755
# 4=>8                  0.500856                 0.830707
# 8=>15                 0.664389                 0.539925
#
#        managers_full_training  managers_training_NA  labor_per_ha
# 0                    0.357771              0.397908      0.132719
# <2k                  0.082218              0.448614      0.207966
# 2=>4                 0.337640              0.364980      0.171287
# 4=>8                 0.472009              0.322099      0.128816
# 8=>15                0.618670              0.167840      0.022996

# %%
df_corrs_standard_output.plot(
    legend=False,
    title="Correlation vs. Standard Output",
    xlabel="Standard Output",
    ylabel="Correlation coefficient"
)
# Out:
# <AxesSubplot:title={'center':'Correlation vs. Standard Output'}, xlabel='Standard Output', ylabel='Correlation coefficient'>

# %%
# Use this for the legend
df_corrs_standard_output.plot(
    legend=True,
    title="Correlation vs. Standard Output",
    xlabel="Standard Output",
    ylabel="Correlation coefficient"
)
# Out:
# <AxesSubplot:title={'center':'Correlation vs. Standard Output'}, xlabel='Standard Output', ylabel='Correlation coefficient'>

# %%
df_corrs_standard_output.style.background_gradient(cmap ='plasma')
# Out:
# <style type="text/css">
# #T_09266_row0_col0, #T_09266_row9_col2 {
#   background-color: #f5eb27;
#   color: #000000;
# }
# #T_09266_row0_col1, #T_09266_row2_col6 {
#   background-color: #6a00a8;
#   color: #f1f1f1;
# }
# #T_09266_row0_col2, #T_09266_row8_col12 {
#   background-color: #4c02a1;
#   color: #f1f1f1;
# }
# #T_09266_row0_col3 {
#   background-color: #fcd025;
#   color: #000000;
# }
# #T_09266_row0_col4, #T_09266_row3_col4 {
#   background-color: #f4ed27;
#   color: #000000;
# }
# #T_09266_row0_col5 {
#   background-color: #fdc627;
#   color: #000000;
# }
# #T_09266_row0_col6, #T_09266_row2_col7, #T_09266_row6_col3 {
#   background-color: #5302a3;
#   color: #f1f1f1;
# }
# #T_09266_row0_col7 {
#   background-color: #4903a0;
#   color: #f1f1f1;
# }
# #T_09266_row0_col8, #T_09266_row3_col7, #T_09266_row5_col3 {
#   background-color: #7b02a8;
#   color: #f1f1f1;
# }
# #T_09266_row0_col9 {
#   background-color: #f8e125;
#   color: #000000;
# }
# #T_09266_row0_col10 {
#   background-color: #c33d80;
#   color: #f1f1f1;
# }
# #T_09266_row0_col11 {
#   background-color: #fdc527;
#   color: #000000;
# }
# #T_09266_row0_col12 {
#   background-color: #feb72d;
#   color: #000000;
# }
# #T_09266_row1_col0 {
#   background-color: #f9dd25;
#   color: #000000;
# }
# #T_09266_row1_col1, #T_09266_row1_col2, #T_09266_row1_col6, #T_09266_row1_col7, #T_09266_row1_col8, #T_09266_row1_col10, #T_09266_row6_col11, #T_09266_row9_col0, #T_09266_row9_col4, #T_09266_row10_col3, #T_09266_row10_col5, #T_09266_row10_col9, #T_09266_row10_col12 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_09266_row1_col3, #T_09266_row1_col9, #T_09266_row1_col11, #T_09266_row1_col12, #T_09266_row2_col0, #T_09266_row2_col4, #T_09266_row3_col5, #T_09266_row6_col8, #T_09266_row6_col10, #T_09266_row8_col1, #T_09266_row8_col2, #T_09266_row8_col6, #T_09266_row8_col7 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_09266_row1_col4, #T_09266_row4_col10, #T_09266_row9_col1 {
#   background-color: #fbd324;
#   color: #000000;
# }
# #T_09266_row1_col5 {
#   background-color: #e76e5b;
#   color: #f1f1f1;
# }
# #T_09266_row2_col1 {
#   background-color: #7701a8;
#   color: #f1f1f1;
# }
# #T_09266_row2_col2, #T_09266_row8_col5 {
#   background-color: #6c00a8;
#   color: #f1f1f1;
# }
# #T_09266_row2_col3, #T_09266_row9_col6 {
#   background-color: #fcce25;
#   color: #000000;
# }
# #T_09266_row2_col5 {
#   background-color: #fbd724;
#   color: #000000;
# }
# #T_09266_row2_col8 {
#   background-color: #bc3587;
#   color: #f1f1f1;
# }
# #T_09266_row2_col9, #T_09266_row7_col2 {
#   background-color: #f8df25;
#   color: #000000;
# }
# #T_09266_row2_col10 {
#   background-color: #bb3488;
#   color: #f1f1f1;
# }
# #T_09266_row2_col11 {
#   background-color: #fca537;
#   color: #000000;
# }
# #T_09266_row2_col12, #T_09266_row4_col5, #T_09266_row7_col1 {
#   background-color: #fad824;
#   color: #000000;
# }
# #T_09266_row3_col0 {
#   background-color: #f6e626;
#   color: #000000;
# }
# #T_09266_row3_col1 {
#   background-color: #aa2395;
#   color: #f1f1f1;
# }
# #T_09266_row3_col2, #T_09266_row3_col6 {
#   background-color: #99159f;
#   color: #f1f1f1;
# }
# #T_09266_row3_col3, #T_09266_row5_col5 {
#   background-color: #fa9c3c;
#   color: #000000;
# }
# #T_09266_row3_col8 {
#   background-color: #df6263;
#   color: #f1f1f1;
# }
# #T_09266_row3_col9 {
#   background-color: #febb2b;
#   color: #000000;
# }
# #T_09266_row3_col10 {
#   background-color: #ec7754;
#   color: #f1f1f1;
# }
# #T_09266_row3_col11 {
#   background-color: #f0804e;
#   color: #f1f1f1;
# }
# #T_09266_row3_col12, #T_09266_row4_col8 {
#   background-color: #fdb42f;
#   color: #000000;
# }
# #T_09266_row4_col0 {
#   background-color: #f68d45;
#   color: #f1f1f1;
# }
# #T_09266_row4_col1 {
#   background-color: #d6556d;
#   color: #f1f1f1;
# }
# #T_09266_row4_col2 {
#   background-color: #d14e72;
#   color: #f1f1f1;
# }
# #T_09266_row4_col3 {
#   background-color: #be3885;
#   color: #f1f1f1;
# }
# #T_09266_row4_col4 {
#   background-color: #f99a3e;
#   color: #000000;
# }
# #T_09266_row4_col6 {
#   background-color: #cf4c74;
#   color: #f1f1f1;
# }
# #T_09266_row4_col7 {
#   background-color: #b12a90;
#   color: #f1f1f1;
# }
# #T_09266_row4_col9 {
#   background-color: #da5b69;
#   color: #f1f1f1;
# }
# #T_09266_row4_col11 {
#   background-color: #9410a2;
#   color: #f1f1f1;
# }
# #T_09266_row4_col12 {
#   background-color: #e3685f;
#   color: #f1f1f1;
# }
# #T_09266_row5_col0 {
#   background-color: #d5536f;
#   color: #f1f1f1;
# }
# #T_09266_row5_col1 {
#   background-color: #e56b5d;
#   color: #f1f1f1;
# }
# #T_09266_row5_col2 {
#   background-color: #e97257;
#   color: #f1f1f1;
# }
# #T_09266_row5_col4 {
#   background-color: #dc5d67;
#   color: #f1f1f1;
# }
# #T_09266_row5_col6 {
#   background-color: #e56a5d;
#   color: #f1f1f1;
# }
# #T_09266_row5_col7 {
#   background-color: #c9447a;
#   color: #f1f1f1;
# }
# #T_09266_row5_col8, #T_09266_row5_col10 {
#   background-color: #f7e425;
#   color: #000000;
# }
# #T_09266_row5_col9 {
#   background-color: #a62098;
#   color: #f1f1f1;
# }
# #T_09266_row5_col11 {
#   background-color: #2f0596;
#   color: #f1f1f1;
# }
# #T_09266_row5_col12, #T_09266_row10_col8 {
#   background-color: #c23c81;
#   color: #f1f1f1;
# }
# #T_09266_row6_col0 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_09266_row6_col1, #T_09266_row6_col6 {
#   background-color: #f58c46;
#   color: #f1f1f1;
# }
# #T_09266_row6_col2 {
#   background-color: #f9983e;
#   color: #000000;
# }
# #T_09266_row6_col4 {
#   background-color: #c43e7f;
#   color: #f1f1f1;
# }
# #T_09266_row6_col5 {
#   background-color: #f07f4f;
#   color: #f1f1f1;
# }
# #T_09266_row6_col7, #T_09266_row8_col10 {
#   background-color: #e26660;
#   color: #f1f1f1;
# }
# #T_09266_row6_col9 {
#   background-color: #7d03a8;
#   color: #f1f1f1;
# }
# #T_09266_row6_col12 {
#   background-color: #a51f99;
#   color: #f1f1f1;
# }
# #T_09266_row7_col0 {
#   background-color: #920fa3;
#   color: #f1f1f1;
# }
# #T_09266_row7_col3 {
#   background-color: #330597;
#   color: #f1f1f1;
# }
# #T_09266_row7_col4 {
#   background-color: #9c179e;
#   color: #f1f1f1;
# }
# #T_09266_row7_col5 {
#   background-color: #d04d73;
#   color: #f1f1f1;
# }
# #T_09266_row7_col6 {
#   background-color: #fada24;
#   color: #000000;
# }
# #T_09266_row7_col7 {
#   background-color: #fdb22f;
#   color: #000000;
# }
# #T_09266_row7_col8, #T_09266_row10_col2 {
#   background-color: #f1f525;
#   color: #000000;
# }
# #T_09266_row7_col9 {
#   background-color: #5102a3;
#   color: #f1f1f1;
# }
# #T_09266_row7_col10 {
#   background-color: #fec029;
#   color: #000000;
# }
# #T_09266_row7_col11 {
#   background-color: #8808a6;
#   color: #f1f1f1;
# }
# #T_09266_row7_col12 {
#   background-color: #7401a8;
#   color: #f1f1f1;
# }
# #T_09266_row8_col0 {
#   background-color: #48039f;
#   color: #f1f1f1;
# }
# #T_09266_row8_col3 {
#   background-color: #1d068e;
#   color: #f1f1f1;
# }
# #T_09266_row8_col4, #T_09266_row9_col11 {
#   background-color: #4b03a1;
#   color: #f1f1f1;
# }
# #T_09266_row8_col8 {
#   background-color: #e97158;
#   color: #f1f1f1;
# }
# #T_09266_row8_col9 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_09266_row8_col11, #T_09266_row10_col10 {
#   background-color: #910ea3;
#   color: #f1f1f1;
# }
# #T_09266_row9_col3, #T_09266_row10_col0 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_09266_row9_col5, #T_09266_row9_col9, #T_09266_row10_col4 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_09266_row9_col7 {
#   background-color: #f5e926;
#   color: #000000;
# }
# #T_09266_row9_col8 {
#   background-color: #a01a9c;
#   color: #f1f1f1;
# }
# #T_09266_row9_col10 {
#   background-color: #c03a83;
#   color: #f1f1f1;
# }
# #T_09266_row9_col12 {
#   background-color: #3c049b;
#   color: #f1f1f1;
# }
# #T_09266_row10_col1 {
#   background-color: #feb82c;
#   color: #000000;
# }
# #T_09266_row10_col6, #T_09266_row10_col7 {
#   background-color: #fdaf31;
#   color: #000000;
# }
# #T_09266_row10_col11 {
#   background-color: #5b01a5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09266">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09266_level0_col0" class="col_heading level0 col0" >farms_number</th>
#       <th id="T_09266_level0_col1" class="col_heading level0 col1" >used_agricultural_area_ha</th>
#       <th id="T_09266_level0_col2" class="col_heading level0 col2" >standard_output_EUR</th>
#       <th id="T_09266_level0_col3" class="col_heading level0 col3" >subsistence_semisubsistence_farms</th>
#       <th id="T_09266_level0_col4" class="col_heading level0 col4" >total_labour_persons</th

# %% [markdown]
# ## What does this chart show us?
# - There are clear factors that make a difference when it comes to the euro output of a farm.
# - If a line goes up and to the right, it means that as this improves euro output should improve as well
# - If a line goes down and to the right, it means that as this value lowers the euro output should improve
# - Extreme values are better. A correlation that goes from 0=> is stronger than one that goes from .49=>.51
#
# ### Findings
# - The more farms there are the lower the average standard output
#     - If there are more farms, we can expect less higher achieving farms
#     - Don't ever get to economies of scale
# - More subsistence farms indicates lower levels of output
#     - correlcation of 0.954061 with managers only having practical training
#     - Tight correlation with farm size, and standard output
# - Less labour is higher output
#     - more efficient use of resources
#     - correlates tightly with number of farms. Economies of scale question, again
# - Manager training makes a difference... up to a point
#     - Farmers with higher output have some level of management training, but this doesn't matter at the highest levels
#     - This is not definitive
# - More non-family labour people, means a higher standard output

# %%
df_sub_farm = df.copy()

df_sub_farm["per_farm_subsistence"] = df_sub_farm.subsistence_semisubsistence_farms / df_sub_farm.farms_number
df_sub_farm["per_farm_subsistence"] = df_sub_farm["per_farm_subsistence"].fillna(0)
# df_sub_farm["per_farm_subsistence"].dropna()
# df_sub_farm = df_sub_farm["per_farm_subsistence"].fillna(0)
df_sub_farm = df_sub_farm.sort_values(by='per_farm_subsistence')
f, ax = plt.subplots(figsize=(10, 10))
df_sub_farm.plot(ax = ax, x = "Country", y = "per_farm_subsistence", 
        kind = "barh", title = "% of Subsistence Farms of Total Farms")
# Out:
# <AxesSubplot:title={'center':'% of Subsistence Farms of Total Farms'}, ylabel='Country'>

# %% [markdown]
# ## What does this show?
# - Shows what % of subsistence farms (consume 50% or more of their output)
# - Weird suspicion that Bulgaria is under reporting
#     - From a development perspective it is far behind all the other nations that report 0
#     - Could be a missing data point that I turned to a zero, before
# - Would be interesting to see what this looks like geographically.
# - Subsistence farms also have the highest correlation witih **only** practical experience
#     - This means that they could be sacrificing yields with some of their practices
#     - Probably run less sustainably, and with less care for numbers

# %%
central_lon, central_lat = -5, 55
extent = [-20, 40, 30, 60]

plt.figure()
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat))

for i in df_sub_farm.itertuples():
    # print(i.CountryCode)
#     plt.text(i.CapitalLongitude, i.CapitalLatitude, i.CountryCode)
    ax.scatter(
        i.CapitalLongitude, 
        i.CapitalLatitude, 
        s=i.per_farm_subsistence * 1000,
        transform=ccrs.PlateCarree()
    )

ax.set_extent(extent)
ax.coastlines(resolution='50m')
ax.add_feature(cartopy.feature.BORDERS)

plt.show()
# Out:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:

# %% [markdown]
# ## Data I would like
# - Farm level data
#     - Country
#     - Output
#     - Methods (Conventional, Organic, Regenerative)
#     - Products
# - Better segmentation
# - Combine with GDP data
# ## Considerations
# - When you look at the way the current CAP is set up it's a one size fits all policy for Europe
#     - Not beneficial to small farmers in developing nations
#     - Half of the EU's expenditures are from this bill
#     - Does 2 things
#         - Support Agricultural Production
#         - Rural Development Policy
#     - Support from CAP comes from
