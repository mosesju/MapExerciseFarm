# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy

import numpy as np
from sklearn import preprocessing

# %%
central_lon, central_lat = -5, 55
extent = [-20, 30, 30, 60]

plt.figure()
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat))
ax.set_extent(extent)
ax.coastlines(resolution='50m')
ax.add_feature(cartopy.feature.BORDERS)
# Out:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:

# %%
df_farms = pd.read_csv('EuropeanAgriculture_FarmStructureIndicators_Eurostat2016.csv')
df_farms.head()
# Out:
#     Country  farms_number  used_agricultural_area_ha  standard_output_EUR  \
# 0   Belgium         36890                    1354250         8.037986e+09
# 1  Bulgaria        202720                    4468500         3.842891e+09
# 2   Czechia         26530                    3455410                  NaN
# 3   Denmark         35050                    2614600         1.006244e+10
# 4   Germany        276120                   16715320         4.924902e+10
#
#    subsistence_semisubsistence_farms  total_labour_persons  total_labour_AWU  \
# 0                                NaN                 70910             55350
# 1                                0.0                439740            255520
# 2                             4120.0                130290            103270
# 3                                0.0                 73320             49480
# 4                                0.0                653760            502610
#
#    nonfamily_labour_persons  nonfamily_labour_AWU  managers_basic_training  \
# 0                   19800.0               14810.0                     9940
# 1                   64490.0               59100.0                     5360
# 2                   81840.0               71440.0                     4910
# 3                   25780.0               22840.0                    16340
# 4                  178640.0              148330.0                   133520
#
#    ...  farms_SO_less2000  farms_SO_2000-3999  farms_SO_4000-7999  \
# 0  ...                310                 580                1380
# 1  ...             105730               35210               22440
# 2  ...               1150                2840                4350
# 3  ...                600                 790                2480
# 4  ...                460                6790               21510
#
#    farms_SO_8000-14999  farms_SO_15000-24999  farms_SO_25000-49999  \
# 0                 2410                  2670                  4310
# 1                13590                  8450                  6780
# 2                 4320                  3050                  3200
# 3                 4920                  4740                  5510
# 4                33650                 29560                 37200
#
#    farms_SO_50000-99999  farms_SO_100000-249999  farms_SO_250000-499999  \
# 0                  5130                    9010                    7170
# 1                  4040                    2740                    1480
# 2                  2400                    2230                     980
# 3                  4260                    3910                    2170
# 4                 40100                   53820                   32350
#
#    farms_SO_500000_orover
# 0                    3880
# 1                    1510
# 2                    1930
# 3                    5510
# 4                   20430
#
# [5 rows x 24 columns]

# %%
df_coords = pd.read_csv('country-capitals.csv',on_bad_lines='skip')
df_coords.head()
# Out:
#                                 CountryName        CapitalName  \
# 0                                Somaliland           Hargeisa
# 1  South Georgia and South Sandwich Islands  King Edward Point
# 2       French Southern and Antarctic Lands  Port-aux-Français
# 3                                 Palestine          Jerusalem
# 4                             Aland Islands          Mariehamn
#
#    CapitalLatitude  CapitalLongitude CountryCode ContinentName
# 0         9.550000         44.050000         NaN        Africa
# 1       -54.283333        -36.500000          GS    Antarctica
# 2       -49.350000         70.216667          TF    Antarctica
# 3        31.766667         35.233333          PS          Asia
# 4        60.116667         19.900000          AX        Europe

# %%
df = pd.merge(
    df_farms, 
    df_coords, 
    how="left", 
    left_on="Country", 
    right_on="CountryName"
)
df = df.drop(['CountryName','ContinentName'], axis=1)
df.head()
# Out:
#     Country  farms_number  used_agricultural_area_ha  standard_output_EUR  \
# 0   Belgium         36890                    1354250         8.037986e+09
# 1  Bulgaria        202720                    4468500         3.842891e+09
# 2   Czechia         26530                    3455410                  NaN
# 3   Denmark         35050                    2614600         1.006244e+10
# 4   Germany        276120                   16715320         4.924902e+10
#
#    subsistence_semisubsistence_farms  total_labour_persons  total_labour_AWU  \
# 0                                NaN                 70910             55350
# 1                                0.0                439740            255520
# 2                             4120.0                130290            103270
# 3                                0.0                 73320             49480
# 4                                0.0                653760            502610
#
#    nonfamily_labour_persons  nonfamily_labour_AWU  managers_basic_training  \
# 0                   19800.0               14810.0                     9940
# 1                   64490.0               59100.0                     5360
# 2                   81840.0               71440.0                     4910
# 3                   25780.0               22840.0                    16340
# 4                  178640.0              148330.0                   133520
#
#    ...  farms_SO_15000-24999  farms_SO_25000-49999  farms_SO_50000-99999  \
# 0  ...                  2670                  4310                  5130
# 1  ...                  8450                  6780                  4040
# 2  ...                  3050                  3200                  2400
# 3  ...                  4740                  5510                  4260
# 4  ...                 29560                 37200                 40100
#
#    farms_SO_100000-249999  farms_SO_250000-499999  farms_SO_500000_orover  \
# 0                    9010                    7170                    3880
# 1                    2740                    1480                    1510
# 2                    2230                     980                    1930
# 3                    3910                    2170                    5510
# 4                   53820                   32350                   20430
#
#    CapitalName  CapitalLatitude  CapitalLongitude  CountryCode
# 0     Brussels        50.833333          4.333333           BE
# 1        Sofia        42.683333         23.316667           BG
# 2          NaN              NaN               NaN          NaN
# 3   Copenhagen        55.666667         12.583333           DK
# 4       Berlin        52.516667         13.400000           DE
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Looking at data (above)
# - Could be interesting to see how the distribution of farms changes using the farm_SO_(value) columns
#     - A stacked bar graph could give. a quick check of what is actually happening in each nation as far as income distribution goes
#     - Done
# - Take a closer look at subsistence farms
#     - How do these correlate with
# - How do all of these metrics correlate with agricultural output?
#     - More subsistence farms higher or lower output => what nuance is this missing?
# - How does manager training impact output at a country level?
#     - Need more context as to what the training actually means?
# - Plot laborers per farm and per ha on a map
#     - What countries are using their resources most effectively
#
# ## Scale Columns
# - Normalizes the data so it's easier for me to scale variables
# - Makes it easier to compare similar data points for the chart

# %%
def scaleColumns(df, cols_to_scale):
    for col in cols_to_scale:
        new_col_name = col+'_normalized'
        df[new_col_name] = pd.DataFrame(min_max_scaler.fit_transform(pd.DataFrame(df[col])),columns=[col]) * 1000
    return df

# %%
min_max_scaler = preprocessing.MinMaxScaler()

df = scaleColumns(df, ['farms_number','used_agricultural_area_ha','standard_output_EUR'])

# %%
central_lon, central_lat = -5, 55
extent = [-20, 30, 30, 60]

plt.figure()
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat))

# print(df['CapitalLongitude'], df['CapitalLatitude'])
cmap = plt.cm.rainbow

for i in df.itertuples():
    plt.text(i.CapitalLongitude, i.CapitalLatitude, i.CountryCode)
    ax.scatter(
        i.CapitalLongitude, 
        i.CapitalLatitude, 
        s=i.used_agricultural_area_ha_normalized,
        # s=i.farms_number_normalized,
        # color='blue', 
        # color = cmap(i.used_agricultural_area_ha_normalized),
        # color = cmap(i.farms_number_normalized),
        transform=ccrs.PlateCarree()
    )

ax.set_extent(extent)
ax.coastlines(resolution='50m')
ax.add_feature(cartopy.feature.BORDERS)

plt.show()
# plt.savefig('used_agricultural_area_ha_normalized')
# Out:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/julian/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
df_stacked = df[[
    'CountryCode',
    'farms_SO_zero',
    'farms_SO_less2000',
    'farms_SO_2000-3999',
    'farms_SO_4000-7999',
    'farms_SO_8000-14999',
    'farms_SO_15000-24999',
    'farms_SO_25000-49999',
    'farms_SO_50000-99999',
    'farms_SO_100000-249999',
    'farms_SO_250000-499999',
    'farms_SO_500000_orover'
    ]].copy()
df_stacked = df_stacked.set_index('CountryCode')
df_stacked.plot(kind='bar', stacked=True, legend=False)
# Out:
# <AxesSubplot:xlabel='CountryCode'>

# %% [markdown]
# ## What does this show us?
# - The vast majority of european farmers are Romanians that have an output of less than 2.000 euros
# - Not exactly sure what the output metric means
#     - data describes it as: *Number of farms with a Standard Output between 2.000-3.999 euros*
# - What is the output / acre on these smaller farms?
# - Why do so many of them exist in Romania?

# %%
# Correlation matrix 
df_corrs = df.corr()
df_corrs.style.background_gradient(cmap ='plasma')
# Out:
# <style type="text/css">
# #T_40998_row0_col0, #T_40998_row0_col4, #T_40998_row0_col25, #T_40998_row1_col1, #T_40998_row1_col26, #T_40998_row2_col2, #T_40998_row2_col27, #T_40998_row3_col3, #T_40998_row4_col0, #T_40998_row4_col4, #T_40998_row4_col25, #T_40998_row5_col5, #T_40998_row6_col6, #T_40998_row7_col7, #T_40998_row8_col8, #T_40998_row9_col9, #T_40998_row10_col10, #T_40998_row11_col11, #T_40998_row12_col12, #T_40998_row13_col13, #T_40998_row14_col14, #T_40998_row15_col15, #T_40998_row16_col16, #T_40998_row17_col17, #T_40998_row18_col18, #T_40998_row19_col19, #T_40998_row20_col20, #T_40998_row21_col21, #T_40998_row22_col22, #T_40998_row23_col23, #T_40998_row24_col24, #T_40998_row25_col0, #T_40998_row25_col4, #T_40998_row25_col25, #T_40998_row26_col1, #T_40998_row26_col26, #T_40998_row27_col2, #T_40998_row27_col27 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_40998_row0_col1, #T_40998_row0_col26, #T_40998_row18_col14, #T_40998_row25_col1, #T_40998_row25_col26 {
#   background-color: #e16462;
#   color: #f1f1f1;
# }
# #T_40998_row0_col2, #T_40998_row0_col8, #T_40998_row0_col27, #T_40998_row11_col3, #T_40998_row12_col10, #T_40998_row25_col2, #T_40998_row25_col8, #T_40998_row25_col27 {
#   background-color: #c7427c;
#   color: #f1f1f1;
# }
# #T_40998_row0_col3, #T_40998_row2_col19, #T_40998_row5_col0, #T_40998_row5_col16, #T_40998_row5_col25, #T_40998_row25_col3, #T_40998_row27_col19 {
#   background-color: #fbd524;
#   color: #000000;
# }
# #T_40998_row0_col5, #T_40998_row1_col2, #T_40998_row1_col27, #T_40998_row2_col1, #T_40998_row2_col26, #T_40998_row5_col14, #T_40998_row7_col21, #T_40998_row25_col5, #T_40998_row26_col2, #T_40998_row26_col27, #T_40998_row27_col1, #T_40998_row27_col26 {
#   background-color: #fbd324;
#   color: #000000;
# }
# #T_40998_row0_col6, #T_40998_row1_col8, #T_40998_row4_col2, #T_40998_row4_col27, #T_40998_row9_col1, #T_40998_row9_col26, #T_40998_row10_col4, #T_40998_row22_col17, #T_40998_row25_col6, #T_40998_row26_col8 {
#   background-color: #cb4679;
#   color: #f1f1f1;
# }
# #T_40998_row0_col7, #T_40998_row10_col0, #T_40998_row10_col25, #T_40998_row14_col6, #T_40998_row25_col7 {
#   background-color: #be3885;
#   color: #f1f1f1;
# }
# #T_40998_row0_col9, #T_40998_row15_col5, #T_40998_row18_col19, #T_40998_row25_col9 {
#   background-color: #f7e425;
#   color: #000000;
# }
# #T_40998_row0_col10, #T_40998_row6_col4, #T_40998_row11_col12, #T_40998_row15_col7, #T_40998_row15_col11, #T_40998_row18_col12, #T_40998_row25_col10 {
#   background-color: #bf3984;
#   color: #f1f1f1;
# }
# #T_40998_row0_col11, #T_40998_row8_col1, #T_40998_row8_col26, #T_40998_row16_col7, #T_40998_row16_col13, #T_40998_row17_col12, #T_40998_row25_col11 {
#   background-color: #d6556d;
#   color: #f1f1f1;
# }
# #T_40998_row0_col12, #T_40998_row4_col12, #T_40998_row14_col12, #T_40998_row25_col12 {
#   background-color: #f5eb27;
#   color: #000000;
# }
# #T_40998_row0_col13, #T_40998_row9_col4, #T_40998_row25_col13 {
#   background-color: #f8e125;
#   color: #000000;
# }
# #T_40998_row0_col14, #T_40998_row3_col13, #T_40998_row13_col3, #T_40998_row25_col14 {
#   background-color: #f0f724;
#   color: #000000;
# }
# #T_40998_row0_col15, #T_40998_row3_col9, #T_40998_row20_col21, #T_40998_row21_col20, #T_40998_row25_col15 {
#   background-color: #f5e926;
#   color: #000000;
# }
# #T_40998_row0_col16, #T_40998_row3_col15, #T_40998_row25_col16 {
#   background-color: #fca835;
#   color: #000000;
# }
# #T_40998_row0_col17, #T_40998_row17_col20, #T_40998_row25_col17 {
#   background-color: #ed7953;
#   color: #f1f1f1;
# }
# #T_40998_row0_col18, #T_40998_row15_col10, #T_40998_row25_col18 {
#   background-color: #db5c68;
#   color: #f1f1f1;
# }
# #T_40998_row0_col19, #T_40998_row4_col6, #T_40998_row5_col22, #T_40998_row12_col11, #T_40998_row15_col2, #T_40998_row15_col27, #T_40998_row17_col21, #T_40998_row19_col4, #T_40998_row25_col19 {
#   background-color: #ce4b75;
#   color: #f1f1f1;
# }
# #T_40998_row0_col20, #T_40998_row12_col19, #T_40998_row14_col24, #T_40998_row25_col20 {
#   background-color: #b7318a;
#   color: #f1f1f1;
# }
# #T_40998_row0_col21, #T_40998_row1_col13, #T_40998_row25_col21, #T_40998_row26_col13 {
#   background-color: #a21d9a;
#   color: #f1f1f1;
# }
# #T_40998_row0_col22, #T_40998_row11_col7, #T_40998_row11_col22, #T_40998_row12_col7, #T_40998_row14_col20, #T_40998_row25_col22 {
#   background-color: #a72197;
#   color: #f1f1f1;
# }
# #T_40998_row0_col23, #T_40998_row2_col24, #T_40998_row24_col18, #T_40998_row25_col23, #T_40998_row27_col24 {
#   background-color: #220690;
#   color: #f1f1f1;
# }
# #T_40998_row0_col24, #T_40998_row25_col24 {
#   background-color: #b02991;
#   color: #f1f1f1;
# }
# #T_40998_row1_col0, #T_40998_row1_col25, #T_40998_row7_col10, #T_40998_row8_col5, #T_40998_row26_col0, #T_40998_row26_col25 {
#   background-color: #da5a6a;
#   color: #f1f1f1;
# }
# #T_40998_row1_col3, #T_40998_row13_col2, #T_40998_row13_col7, #T_40998_row13_col27, #T_40998_row24_col4, #T_40998_row26_col3 {
#   background-color: #8e0ca4;
#   color: #f1f1f1;
# }
# #T_40998_row1_col4, #T_40998_row6_col8, #T_40998_row18_col0, #T_40998_row18_col25, #T_40998_row26_col4 {
#   background-color: #dd5e66;
#   color: #f1f1f1;
# }
# #T_40998_row1_col5, #T_40998_row5_col19, #T_40998_row20_col18, #T_40998_row26_col5 {
#   background-color: #f58b47;
#   color: #f1f1f1;
# }
# #T_40998_row1_col6, #T_40998_row2_col21, #T_40998_row4_col5, #T_40998_row4_col9, #T_40998_row5_col4, #T_40998_row6_col20, #T_40998_row20_col6, #T_40998_row21_col22, #T_40998_row22_col21, #T_40998_row26_col6, #T_40998_row27_col21 {
#   background-color: #f8df25;
#   color: #000000;
# }
# #T_40998_row1_col7, #T_40998_row3_col0, #T_40998_row3_col25, #T_40998_row4_col13, #T_40998_row7_col1, #T_40998_row7_col26, #T_40998_row13_col12, #T_40998_row15_col12, #T_40998_row15_col16, #T_40998_row16_col15, #T_40998_row26_col7 {
#   background-color: #fad824;
#   color: #000000;
# }
# #T_40998_row1_col9, #T_40998_row13_col1, #T_40998_row13_col26, #T_40998_row14_col2, #T_40998_row14_col27, #T_40998_row26_col9 {
#   background-color: #bb3488;
#   color: #f1f1f1;
# }
# #T_40998_row1_col10, #T_40998_row26_col10 {
#   background-color: #e06363;
#   color: #f1f1f1;
# }
# #T_40998_row1_col11, #T_40998_row7_col8, #T_40998_row13_col24, #T_40998_row26_col11 {
#   background-color: #c13b82;
#   color: #f1f1f1;
# }
# #T_40998_row1_col12, #T_40998_row7_col4, #T_40998_row22_col5, #T_40998_row26_col12 {
#   background-color: #b6308b;
#   color: #f1f1f1;
# }
# #T_40998_row1_col14, #T_40998_row5_col21, #T_40998_row14_col8, #T_40998_row26_col14 {
#   background-color: #cd4a76;
#   color: #f1f1f1;
# }
# #T_40998_row1_col15, #T_40998_row8_col22, #T_40998_row9_col11, #T_40998_row26_col15 {
#   background-color: #de6164;
#   color: #f1f1f1;
# }
# #T_40998_row1_col16, #T_40998_row26_col16 {
#   background-color: #ee7b51;
#   color: #f1f1f1;
# }
# #T_40998_row1_col17, #T_40998_row3_col5, #T_40998_row17_col6, #T_40998_row26_col17 {
#   background-color: #f3854b;
#   color: #f1f1f1;
# }
# #T_40998_row1_col18, #T_40998_row26_col18 {
#   background-color: #f89441;
#   color: #000000;
# }
# #T_40998_row1_col19, #T_40998_row26_col19 {
#   background-color: #febe2a;
#   color: #000000;
# }
# #T_40998_row1_col20, #T_40998_row3_col14, #T_40998_row14_col5, #T_40998_row16_col5, #T_40998_row19_col20, #T_40998_row21_col7, #T_40998_row26_col20 {
#   background-color: #fcd225;
#   color: #000000;
# }
# #T_40998_row1_col21, #T_40998_row19_col1, #T_40998_row19_col26, #T_40998_row26_col21 {
#   background-color: #fdc229;
#   color: #000000;
# }
# #T_40998_row1_col22, #T_40998_row26_col22 {
#   background-color: #feb72d;
#   color: #000000;
# }
# #T_40998_row1_col23, #T_40998_row26_col23 {
#   background-color: #5601a4;
#   color: #f1f1f1;
# }
# #T_40998_row1_col24, #T_40998_row21_col3, #T_40998_row26_col24 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_40998_row2_col0, #T_40998_row2_col25, #T_40998_row7_col15, #T_40998_row16_col21, #T_40998_row21_col5, #T_40998_row27_col0, #T_40998_row27_col25 {
#   background-color: #b83289;
#   color: #f1f1f1;
# }
# #T_40998_row2_col3, #T_40998_row6_col3, #T_40998_row22_col9, #T_40998_row27_col3 {
#   background-color: #4c02a1;
#   color: #f1f1f1;
# }
# #T_40998_row2_col4, #T_40998_row3_col24, #T_40998_row6_col0, #T_40998_row6_col25, #T_409

# %%
df_corrs_standard_output = df_corrs[['farms_SO_zero',
    'farms_SO_less2000',
    'farms_SO_2000-3999',
    'farms_SO_4000-7999',
    'farms_SO_8000-14999',
    'farms_SO_15000-24999',
    'farms_SO_25000-49999',
    'farms_SO_50000-99999',
    'farms_SO_100000-249999',
    'farms_SO_250000-499999',
    'farms_SO_500000_orover'
]]

# %%
df_corrs_standard_output = df_corrs_standard_output.rename(columns={
    'farms_SO_zero':'0',
    'farms_SO_less2000': '<2k',
    'farms_SO_2000-3999': '2=>4',
    'farms_SO_4000-7999': '4=>8',
    'farms_SO_8000-14999': '8=>15',
    'farms_SO_15000-24999': '15=>25',
    'farms_SO_25000-49999': '25=>50',
    'farms_SO_50000-99999': '50=>100',
    'farms_SO_100000-249999': '100=>250',
    'farms_SO_250000-499999': '250=>500',
    'farms_SO_500000_orover': '500+'
})
df_corrs_standard_output = df_corrs_standard_output.transpose()
list(df_corrs_standard_output.columns)
df_corrs_standard_output = df_corrs_standard_output.drop(columns=[
    '0',
    '<2k',
    '2=>4',
    '4=>8',
    '8=>15',
    '15=>25',
    '25=>50',
    '50=>100',
    '100=>250',
    '250=>500',
    '500+',
    'CapitalLatitude',
    'CapitalLongitude',
    'farms_number_normalized',
    'used_agricultural_area_ha_normalized',
    'standard_output_EUR_normalized'
])

# %%
df_corrs_standard_output.plot(
    legend=False,
    title="Correlation vs. Standard Output",
    xlabel="Standard Output",
    ylabel="Correlation coefficient"
)
# Out:
# <AxesSubplot:title={'center':'Correlation vs. Standard Output'}, xlabel='Standard Output', ylabel='Correlation coefficient'>

# %%
# Use this for the legend
df_corrs_standard_output.plot(
    legend=True,
    title="Correlation vs. Standard Output",
    xlabel="Standard Output",
    ylabel="Correlation coefficient"
)
# Out:
# <AxesSubplot:title={'center':'Correlation vs. Standard Output'}, xlabel='Standard Output', ylabel='Correlation coefficient'>

# %%
df_corrs_standard_output.style.background_gradient(cmap ='plasma')
# Out:
# <style type="text/css">
# #T_3b955_row0_col0, #T_3b955_row9_col2 {
#   background-color: #f5eb27;
#   color: #000000;
# }
# #T_3b955_row0_col1, #T_3b955_row2_col6 {
#   background-color: #6a00a8;
#   color: #f1f1f1;
# }
# #T_3b955_row0_col2 {
#   background-color: #4c02a1;
#   color: #f1f1f1;
# }
# #T_3b955_row0_col3 {
#   background-color: #fcd025;
#   color: #000000;
# }
# #T_3b955_row0_col4, #T_3b955_row3_col4 {
#   background-color: #f4ed27;
#   color: #000000;
# }
# #T_3b955_row0_col5 {
#   background-color: #fdc627;
#   color: #000000;
# }
# #T_3b955_row0_col6, #T_3b955_row2_col7, #T_3b955_row6_col3 {
#   background-color: #5302a3;
#   color: #f1f1f1;
# }
# #T_3b955_row0_col7 {
#   background-color: #4903a0;
#   color: #f1f1f1;
# }
# #T_3b955_row0_col8, #T_3b955_row3_col7, #T_3b955_row5_col3 {
#   background-color: #7b02a8;
#   color: #f1f1f1;
# }
# #T_3b955_row0_col9 {
#   background-color: #f8e125;
#   color: #000000;
# }
# #T_3b955_row0_col10 {
#   background-color: #c33d80;
#   color: #f1f1f1;
# }
# #T_3b955_row0_col11 {
#   background-color: #fdc527;
#   color: #000000;
# }
# #T_3b955_row1_col0 {
#   background-color: #f9dd25;
#   color: #000000;
# }
# #T_3b955_row1_col1, #T_3b955_row1_col2, #T_3b955_row1_col6, #T_3b955_row1_col7, #T_3b955_row1_col8, #T_3b955_row1_col10, #T_3b955_row6_col11, #T_3b955_row9_col0, #T_3b955_row9_col4, #T_3b955_row10_col3, #T_3b955_row10_col5, #T_3b955_row10_col9 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_3b955_row1_col3, #T_3b955_row1_col9, #T_3b955_row1_col11, #T_3b955_row2_col0, #T_3b955_row2_col4, #T_3b955_row3_col5, #T_3b955_row6_col8, #T_3b955_row6_col10, #T_3b955_row8_col1, #T_3b955_row8_col2, #T_3b955_row8_col6, #T_3b955_row8_col7 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_3b955_row1_col4, #T_3b955_row4_col10, #T_3b955_row9_col1 {
#   background-color: #fbd324;
#   color: #000000;
# }
# #T_3b955_row1_col5 {
#   background-color: #e76e5b;
#   color: #f1f1f1;
# }
# #T_3b955_row2_col1 {
#   background-color: #7701a8;
#   color: #f1f1f1;
# }
# #T_3b955_row2_col2, #T_3b955_row8_col5 {
#   background-color: #6c00a8;
#   color: #f1f1f1;
# }
# #T_3b955_row2_col3, #T_3b955_row9_col6 {
#   background-color: #fcce25;
#   color: #000000;
# }
# #T_3b955_row2_col5 {
#   background-color: #fbd724;
#   color: #000000;
# }
# #T_3b955_row2_col8 {
#   background-color: #bc3587;
#   color: #f1f1f1;
# }
# #T_3b955_row2_col9, #T_3b955_row7_col2 {
#   background-color: #f8df25;
#   color: #000000;
# }
# #T_3b955_row2_col10 {
#   background-color: #bb3488;
#   color: #f1f1f1;
# }
# #T_3b955_row2_col11 {
#   background-color: #fca537;
#   color: #000000;
# }
# #T_3b955_row3_col0 {
#   background-color: #f6e626;
#   color: #000000;
# }
# #T_3b955_row3_col1 {
#   background-color: #aa2395;
#   color: #f1f1f1;
# }
# #T_3b955_row3_col2, #T_3b955_row3_col6 {
#   background-color: #99159f;
#   color: #f1f1f1;
# }
# #T_3b955_row3_col3, #T_3b955_row5_col5 {
#   background-color: #fa9c3c;
#   color: #000000;
# }
# #T_3b955_row3_col8 {
#   background-color: #df6263;
#   color: #f1f1f1;
# }
# #T_3b955_row3_col9 {
#   background-color: #febb2b;
#   color: #000000;
# }
# #T_3b955_row3_col10 {
#   background-color: #ec7754;
#   color: #f1f1f1;
# }
# #T_3b955_row3_col11 {
#   background-color: #f0804e;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col0 {
#   background-color: #f68d45;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col1 {
#   background-color: #d6556d;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col2 {
#   background-color: #d14e72;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col3 {
#   background-color: #be3885;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col4 {
#   background-color: #f99a3e;
#   color: #000000;
# }
# #T_3b955_row4_col5, #T_3b955_row7_col1 {
#   background-color: #fad824;
#   color: #000000;
# }
# #T_3b955_row4_col6 {
#   background-color: #cf4c74;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col7 {
#   background-color: #b12a90;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col8 {
#   background-color: #fdb42f;
#   color: #000000;
# }
# #T_3b955_row4_col9 {
#   background-color: #da5b69;
#   color: #f1f1f1;
# }
# #T_3b955_row4_col11 {
#   background-color: #9410a2;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col0 {
#   background-color: #d5536f;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col1 {
#   background-color: #e56b5d;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col2 {
#   background-color: #e97257;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col4 {
#   background-color: #dc5d67;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col6 {
#   background-color: #e56a5d;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col7 {
#   background-color: #c9447a;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col8, #T_3b955_row5_col10 {
#   background-color: #f7e425;
#   color: #000000;
# }
# #T_3b955_row5_col9 {
#   background-color: #a62098;
#   color: #f1f1f1;
# }
# #T_3b955_row5_col11 {
#   background-color: #2f0596;
#   color: #f1f1f1;
# }
# #T_3b955_row6_col0 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_3b955_row6_col1, #T_3b955_row6_col6 {
#   background-color: #f58c46;
#   color: #f1f1f1;
# }
# #T_3b955_row6_col2 {
#   background-color: #f9983e;
#   color: #000000;
# }
# #T_3b955_row6_col4 {
#   background-color: #c43e7f;
#   color: #f1f1f1;
# }
# #T_3b955_row6_col5 {
#   background-color: #f07f4f;
#   color: #f1f1f1;
# }
# #T_3b955_row6_col7, #T_3b955_row8_col10 {
#   background-color: #e26660;
#   color: #f1f1f1;
# }
# #T_3b955_row6_col9 {
#   background-color: #7d03a8;
#   color: #f1f1f1;
# }
# #T_3b955_row7_col0 {
#   background-color: #920fa3;
#   color: #f1f1f1;
# }
# #T_3b955_row7_col3 {
#   background-color: #330597;
#   color: #f1f1f1;
# }
# #T_3b955_row7_col4 {
#   background-color: #9c179e;
#   color: #f1f1f1;
# }
# #T_3b955_row7_col5 {
#   background-color: #d04d73;
#   color: #f1f1f1;
# }
# #T_3b955_row7_col6 {
#   background-color: #fada24;
#   color: #000000;
# }
# #T_3b955_row7_col7 {
#   background-color: #fdb22f;
#   color: #000000;
# }
# #T_3b955_row7_col8, #T_3b955_row10_col2 {
#   background-color: #f1f525;
#   color: #000000;
# }
# #T_3b955_row7_col9 {
#   background-color: #5102a3;
#   color: #f1f1f1;
# }
# #T_3b955_row7_col10 {
#   background-color: #fec029;
#   color: #000000;
# }
# #T_3b955_row7_col11 {
#   background-color: #8808a6;
#   color: #f1f1f1;
# }
# #T_3b955_row8_col0 {
#   background-color: #48039f;
#   color: #f1f1f1;
# }
# #T_3b955_row8_col3 {
#   background-color: #1d068e;
#   color: #f1f1f1;
# }
# #T_3b955_row8_col4, #T_3b955_row9_col11 {
#   background-color: #4b03a1;
#   color: #f1f1f1;
# }
# #T_3b955_row8_col8 {
#   background-color: #e97158;
#   color: #f1f1f1;
# }
# #T_3b955_row8_col9 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_3b955_row8_col11, #T_3b955_row10_col10 {
#   background-color: #910ea3;
#   color: #f1f1f1;
# }
# #T_3b955_row9_col3, #T_3b955_row10_col0 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_3b955_row9_col5, #T_3b955_row9_col9, #T_3b955_row10_col4 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_3b955_row9_col7 {
#   background-color: #f5e926;
#   color: #000000;
# }
# #T_3b955_row9_col8 {
#   background-color: #a01a9c;
#   color: #f1f1f1;
# }
# #T_3b955_row9_col10 {
#   background-color: #c03a83;
#   color: #f1f1f1;
# }
# #T_3b955_row10_col1 {
#   background-color: #feb82c;
#   color: #000000;
# }
# #T_3b955_row10_col6, #T_3b955_row10_col7 {
#   background-color: #fdaf31;
#   color: #000000;
# }
# #T_3b955_row10_col8 {
#   background-color: #c23c81;
#   color: #f1f1f1;
# }
# #T_3b955_row10_col11 {
#   background-color: #5b01a5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3b955">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b955_level0_col0" class="col_heading level0 col0" >farms_number</th>
#       <th id="T_3b955_level0_col1" class="col_heading level0 col1" >used_agricultural_area_ha</th>
#       <th id="T_3b955_level0_col2" class="col_heading level0 col2" >standard_output_EUR</th>
#       <th id="T_3b955_level0_col3" class="col_heading level0 col3" >subsistence_semisubsistence_farms</th>
#       <th id="T_3b955_level0_col4" class="col_heading level0 col4" >total_labour_persons</th>
#       <th id="T_3b955_level0_col5" class="col_heading level0 col5" >total_labour_AWU</th>
#       <th id="T_3b955_level0_col6" class="col_heading level0 col6" >nonfamily_labour_persons</th>
#       <th id="T_3b955_level0_col7" class="col_heading level0 col7" >nonfamily_labour_AWU</th>
#       <th id="T_3b955_level0_col8" class="col_heading level0 col8" >managers_basic_training</th>
#       <th id="T_3b955_level0_col9" class="col_heading level0 col9" >managers_only_practical</th>

# %% [markdown]
# ## What does this chart show us?
# - There are clear factors that make a difference when it comes to the euro output of a farm.
# - If a line goes up and to the right, it means that as this improves euro output should improve as well
# - If a line goes down and to the right, it means that as this value lowers the euro output should improve
# - Extreme values are better. A correlation that goes from 0=> is stronger than one that goes from .49=>.51
#
# ### Findings
# - The more farms there are the lower the average standard output
#     - If there are more farms, we can expect less higher achieving farms
# - More subsistence farms indicates lower levels of output
# - Less labour is higher output
# - Manager training makes a difference... up to a point

# %% [markdown]
# ## Data I want
# - Farm level data
#     - Country
#     - Output
#     - Methods (Conventional, Organic, Regenerative)
#     - Products
